# %%
import sys
module_path = "/home/work/Dacon-YAI/devch"
sys.path.append(module_path)

import cv2
from cv2 import dnn_superres

# Create an SR object
sr = dnn_superres.DnnSuperResImpl_create()

# Read image
image = cv2.imread('./TEST_000000.png')

# Read the desired model
path = "EDSR_x3.pb"
sr.readModel(path)

# Set the desired model and scale to get correct pre- and post-processing
sr.setModel("edsr", 3)

# Upscale the image
result = sr.upsample(image)

# Save the image
cv2.imwrite("./upscaled.png", result)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 9
#       6 from cv2 import dnn_superres
#       8 # Create an SR object
# ----> 9 sr = dnn_superres.DnnSuperResImpl_create()
#      11 # Read image
#      12 image = cv2.imread('./TEST_000000.png')
#
# AttributeError: module 'cv2.dnn_superres' has no attribute 'DnnSuperResImpl_create'

# %%
import sys
module_path = "/root/dacon"
sys.path.append(module_path)
from models.super_resolution.models import edsr_baseline
import matplotlib.pyplot as plt


model = edsr_baseline(4, True)

# %%
import numpy as np
import torch


origin_image = cv2.imread('/root/dacon/test_file/TEST_00000.png')
# print(image)
plt.imshow(origin_image)


image = torch.Tensor(origin_image) / 255
image = image.permute(2,0,1).unsqueeze(0)
print(image.shape)
output = model(image)
# Out:
# torch.Size([1, 3, 224, 224])

# %%
print(output.shape)
aaa = output.squeeze(0).permute(1,2,0).detach().numpy()
print(aaa.shape)
plt.imshow(aaa)
# aaa
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# torch.Size([1, 3, 896, 896])
# (896, 896, 3)

# %%
import cv2
print(origin_image.shape)
cv2.imwrite("origin.jpeg", origin_image)
cv2.imwrite("upsampled.jpeg", aaa*255)
# Out:
# (224, 224, 3)
# True

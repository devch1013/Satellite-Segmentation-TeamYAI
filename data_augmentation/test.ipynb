# %%
import cv2
import PIL
import matplotlib.pyplot as plt
import torch
from torchvision import transforms

# %%
img = PIL.Image.open("/root/dacon/data/test_img/TEST_00003.png")
img = cv2.Canny(img, 100, 200)
plt.imsave(img, "ddd.jpg")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[2], line 2
#       1 img = PIL.Image.open("/root/dacon/data/test_img/TEST_00003.png")
# ----> 2 img = cv2.Canny(img, 100, 200)
#       3 plt.imsave(img, "ddd.jpg")
#
# error: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'Canny'
# > Overload resolution failed:
# >  - image is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'image'
# >  - Canny() missing required argument 'threshold2' (pos 4)
# >  - Canny() missing required argument 'threshold2' (pos 4)

# %%
img = cv2.imread('/root/dacon/data/test_img/TEST_00003.png')
print(img.shape)

assert img is not None, "file could not be read, check with os.path.exists()"
trans = transforms.Compose([transforms.ToTensor()])
img_tensor = trans(img)
img_tensor = img_tensor.permute(2,1,0)
edges = cv2.Canny(img,150,350)
print(edges.shape)
plt.subplot(131),plt.imshow(img)
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(132),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.subplot(133),plt.imshow(img_tensor)
plt.title('tensor Image'), plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# (224, 224, 3)
# (224, 224)
